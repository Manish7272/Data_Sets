# %% [markdown]
# # Project Description

# %% [markdown]
# This dataset consists of apps needed permissions during installation and run-time. We collect apps from three different sources: google play, third-party apps and malware dataset. This file contains more than 30,000 Android apps. features extracted at the time of installation and execution. One file contains the name of the features and others contain a .apk file corresponding to extracted permissions with respective packages. Apps are collected from Google's play store, hiapk, app china, Android, mumayi , gfan slideme, and pandaapp. These .apk files collected from the last three years continuously contain 81 distinct malware families.
# * But, Here you are only supposed to predict whether the app is benign(0) or malware(1).

# %% [markdown]
# ## Dataset Description

# %% [markdown]
# <ol depth="0" class="list-decimal list-inside my-4 w-11/12">
# <li index="0" class="text-base list-inside py-1 listing w-11/12 text-justify">App :- Name of the App</li>
# <li index="1" class="text-base list-inside py-1 listing w-11/12 text-justify">Package :- OBB/Data package installed in root folder</li>
# <li index="2" class="text-base list-inside py-1 listing w-11/12 text-justify">Category :- App Category (eg. Entertainment, Adventure, puzzle, Action, Antivirus, etc.)</li>
# <li index="3" class="text-base list-inside py-1 listing w-11/12 text-justify">Description :- App Description</li>
# <li index="4" class="text-base list-inside py-1 listing w-11/12 text-justify">Rating :- Rating out of 5</li>
# <li index="5" class="text-base list-inside py-1 listing w-11/12 text-justify">Number of ratings :- No. of Ratings given by users</li>
# <li index="6" class="text-base list-inside py-1 listing w-11/12 text-justify">Price :- Price of the App</li>
# <li index="7" class="text-base list-inside py-1 listing w-11/12 text-justify">Related apps :- Apps related to installed App</li>
# <li index="8" class="text-base list-inside py-1 listing w-11/12 text-justify">Dangerous (D) permissions count :- No. of Dangerous Permissions allowed by user</li>
# <li index="9" class="text-base list-inside py-1 listing w-11/12 text-justify">Safe (S) permissions count :- No. of Safe Permissions allowed by user</li>
# <li index="10" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : Access DRM content. (S) :- 0 : No , 1 : Yes</li>
# <li index="11" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : Access Email provider data (S) :- 0 : No , 1 : Yes</li>
# <li index="12" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : Access all system downloads (S) :- 0 : No , 1 : Yes</li>
# <li index="13" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : Access download manager. (S) :- 0 : No , 1 : Yes</li>
# <li index="14" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : Advanced download manager functions. (S) :- 0 : No , 1 : Yes</li>
# <li index="15" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : Audio File Access (S) :- 0 : No , 1 : Yes</li>
# <li index="16" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : Install DRM content. (S) :- 0 : No , 1 : Yes</li>
# <li index="17" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : Modify Google service configuration (S) :- 0 : No , 1 : Yes</li>
# <li index="18" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : Modify Google settings (S) :- 0 : No , 1 : Yes</li>
# <li index="19" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : Move application resources (S) :- 0 : No , 1 : Yes</li>
# <li index="20" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : Read Google settings (S) :- 0 : No , 1 : Yes</li>
# <li index="21" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : Send download notifications. (S) :- 0 : No , 1 : Yes</li>
# <li index="22" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : Voice Search Shortcuts (S) :- 0 : No , 1 : Yes</li>
# <li index="23" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : access SurfaceFlinger (S) :- 0 : No , 1 : Yes</li>
# <li index="24" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : access checkin properties (S) :- 0 : No , 1 : Yes</li>
# <li index="25" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : access the cache filesystem (S) :- 0 : No , 1 : Yes</li>
# <li index="26" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : access to passwords for Google accounts (S) :- 0 : No , 1 : Yes</li>
# <li index="27" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : act as an account authenticator (S) :- 0 : No , 1 : Yes</li>
# <li index="28" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : bind to a wallpaper (S) :- 0 : No , 1 : Yes</li>
# <li index="29" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : bind to an input method (S) :- 0 : No , 1 : Yes</li>
# <li index="30" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : change screen orientation (S) :- 0 : No , 1 : Yes</li>
# <li index="31" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : coarse (network-based) location (S) :- 0 : No , 1 : Yes</li>
# <li index="32" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : control location update notifications (S) :- 0 : No , 1 : Yes</li>
# <li index="33" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : control system backup and restore (S) :- 0 : No , 1 : Yes</li>
# <li index="34" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : delete applications (S) :- 0 : No , 1 : Yes</li>
# <li index="35" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : delete other applications' caches (S) :- 0 : No , 1 : Yes</li>
# <li index="36" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : delete other applications' data (S) :- 0 : No , 1 : Yes</li>
# <li index="37" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : directly call any phone numbers (S) :- 0 : No , 1 : Yes</li>
# <li index="38" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : directly install applications (S) :- 0 : No , 1 : Yes</li>
# <li index="39" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : disable or modify status bar (S) :- 0 : No , 1 : Yes</li>
# <li index="40" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : discover known accounts (S) :- 0 : No , 1 : Yes</li>
# <li index="41" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : display unauthorized windows (S) :- 0 : No , 1 : Yes</li>
# <li index="42" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : enable or disable application components (S) :- 0 : No , 1 : Yes</li>
# <li index="43" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : force application to close (S) :- 0 : No , 1 : Yes</li>
# <li index="44" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : force device reboot (S) :- 0 : No , 1 : Yes</li>
# <li index="45" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : full Internet access (S) :- 0 : No , 1 : Yes</li>
# <li index="46" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : interact with a device admin (S) :- 0 : No , 1 : Yes</li>
# <li index="47" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : manage application tokens (S) :- 0 : No , 1 : Yes</li>
# <li index="48" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : mock location sources for testing (S) :- 0 : No , 1 : Yes</li>
# <li index="49" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : modify battery statistics (S) :- 0 : No , 1 : Yes</li>
# <li index="50" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : modify secure system settings (S) :- 0 : No , 1 : Yes</li>
# <li index="51" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : modify the Google services map (S) :- 0 : No , 1 : Yes</li>
# <li index="52" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : modify/delete USB storage contents modify/delete SD card contents (S) :- 0 : No , 1 : Yes</li>
# <li index="53" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : monitor and control all application launching (S) :- 0 : No , 1 : Yes</li>
# <li index="54" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : partial shutdown (S) :- 0 : No , 1 : Yes</li>
# <li index="55" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : permanently disable device (S) :- 0 : No , 1 : Yes</li>
# <li index="56" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : permission to install a location provider (S) :- 0 : No , 1 : Yes</li>
# <li index="57" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : power device on or off (S) :- 0 : No , 1 : Yes</li>
# <li index="58" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : press keys and control buttons (S) :- 0 : No , 1 : Yes</li>
# <li index="59" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : prevent app switches (S) :- 0 : No , 1 : Yes</li>
# <li index="60" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : read frame buffer (S) :- 0 : No , 1 : Yes</li>
# <li index="61" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : read instant messages (S) :- 0 : No , 1 : Yes</li>
# <li index="62" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : read phone state and identity (S) :- 0 : No , 1 : Yes</li>
# <li index="63" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : record what you type and actions you take (S) :- 0 : No , 1 : Yes</li>
# <li index="64" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : reset system to factory defaults (S) :- 0 : No , 1 : Yes</li>
# <li index="65" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : run in factory test mode (S) :- 0 : No , 1 : Yes</li>
# <li index="66" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : set time (S) :- 0 : No , 1 : Yes</li>
# <li index="67" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : set wallpaper size hints (S) :- 0 : No , 1 : Yes</li>
# <li index="68" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : start IM service (S) :- 0 : No , 1 : Yes</li>
# <li index="69" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : update component usage statistics (S) :- 0 : No , 1 : Yes</li>
# <li index="70" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : write contact data (S) :- 0 : No , 1 : Yes</li>
# <li index="71" class="text-base list-inside py-1 listing w-11/12 text-justify">Default : write instant messages (S) :- 0 : No , 1 : Yes</li>
# <li index="72" class="text-base list-inside py-1 listing w-11/12 text-justify">Development tools : enable application debugging (D) :- 0 : No , 1 : Yes</li>
# <li index="73" class="text-base list-inside py-1 listing w-11/12 text-justify">Development tools : limit number of running processes (D) :- 0 : No , 1 : Yes</li>
# <li index="74" class="text-base list-inside py-1 listing w-11/12 text-justify">Development tools : make all background applications close (D) :- 0 : No , 1 : Yes</li>
# <li index="75" class="text-base list-inside py-1 listing w-11/12 text-justify">Development tools : send Linux signals to applications (D) :- 0 : No , 1 : Yes</li>
# <li index="76" class="text-base list-inside py-1 listing w-11/12 text-justify">Hardware controls : change your audio settings (D) :- 0 : No , 1 : Yes</li>
# <li index="77" class="text-base list-inside py-1 listing w-11/12 text-justify">Hardware controls : control flashlight (S) :- 0 : No , 1 : Yes</li>
# <li index="78" class="text-base list-inside py-1 listing w-11/12 text-justify">Hardware controls : control vibrator (S) :- 0 : No , 1 : Yes</li>
# <li index="79" class="text-base list-inside py-1 listing w-11/12 text-justify">Hardware controls : record audio (D) :- 0 : No , 1 : Yes</li>
# <li index="80" class="text-base list-inside py-1 listing w-11/12 text-justify">Hardware controls : take pictures and videos (D) :- 0 : No , 1 : Yes</li>
# <li index="81" class="text-base list-inside py-1 listing w-11/12 text-justify">Hardware controls : test hardware (S) :- 0 : No , 1 : Yes</li>
# <li index="82" class="text-base list-inside py-1 listing w-11/12 text-justify">Network communication : Broadcast data messages to applications. (S) :- 0 : No , 1 : Yes</li>
# <li index="83" class="text-base list-inside py-1 listing w-11/12 text-justify">Network communication : control Near Field Communication (D) :- 0 : No , 1 : Yes</li>
# <li index="84" class="text-base list-inside py-1 listing w-11/12 text-justify">Network communication : create Bluetooth connections (D) :- 0 : No , 1 : Yes</li>
# <li index="85" class="text-base list-inside py-1 listing w-11/12 text-justify">Network communication : download files without notification (S) :- 0 : No , 1 : Yes</li>
# <li index="86" class="text-base list-inside py-1 listing w-11/12 text-justify">Network communication : full Internet access (D) :- 0 : No , 1 : Yes</li>
# <li index="87" class="text-base list-inside py-1 listing w-11/12 text-justify">Network communication : make/receive Internet calls (D) :- 0 : No , 1 : Yes</li>
# <li index="88" class="text-base list-inside py-1 listing w-11/12 text-justify">Network communication : receive data from Internet (S) :- 0 : No , 1 : Yes</li>
# <li index="89" class="text-base list-inside py-1 listing w-11/12 text-justify">Network communication : view Wi-Fi state (S) :- 0 : No , 1 : Yes</li>
# <li index="90" class="text-base list-inside py-1 listing w-11/12 text-justify">Network communication : view network state (S) :- 0 : No , 1 : Yes</li>
# <li index="91" class="text-base list-inside py-1 listing w-11/12 text-justify">Phone calls : intercept outgoing calls (D) :- 0 : No , 1 : Yes</li>
# <li index="92" class="text-base list-inside py-1 listing w-11/12 text-justify">Phone calls : modify phone state (S) :- 0 : No , 1 : Yes</li>
# <li index="93" class="text-base list-inside py-1 listing w-11/12 text-justify">Phone calls : read phone state and identity (D) :- 0 : No , 1 : Yes</li>
# <li index="94" class="text-base list-inside py-1 listing w-11/12 text-justify">Services that cost you money : directly call phone numbers (D) :- 0 : No , 1 : Yes</li>
# <li index="95" class="text-base list-inside py-1 listing w-11/12 text-justify">Services that cost you money : send SMS messages (D) :- 0 : No , 1 : Yes</li>
# <li index="96" class="text-base list-inside py-1 listing w-11/12 text-justify">Storage : modify/delete USB storage contents modify/delete SD card contents (D) :- 0 : No , 1 : Yes</li>
# <li index="97" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : allow Wi-Fi Multicast reception (D) :- 0 : No , 1 : Yes</li>
# <li index="98" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : automatically start at boot (S) :- 0 : No , 1 : Yes</li>
# <li index="99" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : bluetooth administration (D) :- 0 : No , 1 : Yes</li>
# <li index="100" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : change Wi-Fi state (D) :- 0 : No , 1 : Yes</li>
# <li index="101" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : change background data usage setting (S) :- 0 : No , 1 : Yes</li>
# <li index="102" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : change network connectivity (D) :- 0 : No , 1 : Yes</li>
# <li index="103" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : change your UI settings (D) :- 0 : No , 1 : Yes</li>
# <li index="104" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : delete all application cache data (D) :- 0 : No , 1 : Yes</li>
# <li index="105" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : disable keylock (D) :- 0 : No , 1 : Yes</li>
# <li index="106" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : display system-level alerts (D) :- 0 : No , 1 : Yes</li>
# <li index="107" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : expand/collapse status bar (S) :- 0 : No , 1 : Yes</li>
# <li index="108" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : force stop other applications (S) :- 0 : No , 1 : Yes</li>
# <li index="109" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : format external storage (D) :- 0 : No , 1 : Yes</li>
# <li index="110" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : kill background processes (S) :- 0 : No , 1 : Yes</li>
# <li index="111" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : make application always run (D) :- 0 : No , 1 : Yes</li>
# <li index="112" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : measure application storage space (S) :- 0 : No , 1 : Yes</li>
# <li index="113" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : modify global animation speed (D) :- 0 : No , 1 : Yes</li>
# <li index="114" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : modify global system settings (D) :- 0 : No , 1 : Yes</li>
# <li index="115" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : mount and unmount filesystems (D) :- 0 : No , 1 : Yes</li>
# <li index="116" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : prevent device from sleeping (D) :- 0 : No , 1 : Yes</li>
# <li index="117" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : read subscribed feeds (S) :- 0 : No , 1 : Yes</li>
# <li index="118" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : read sync settings (S) :- 0 : No , 1 : Yes</li>
# <li index="119" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : read sync statistics (S) :- 0 : No , 1 : Yes</li>
# <li index="120" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : read/write to resources owned by diag (S) :- 0 : No , 1 : Yes</li>
# <li index="121" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : reorder running applications (D) :- 0 : No , 1 : Yes</li>
# <li index="122" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : retrieve running applications (D) :- 0 : No , 1 : Yes</li>
# <li index="123" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : send package removed broadcast (S) :- 0 : No , 1 : Yes</li>
# <li index="124" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : send sticky broadcast (S) :- 0 : No , 1 : Yes</li>
# <li index="125" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : set preferred applications (S) :- 0 : No , 1 : Yes</li>
# <li index="126" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : set time zone (D) :- 0 : No , 1 : Yes</li>
# <li index="127" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : set wallpaper (S) :- 0 : No , 1 : Yes</li>
# <li index="128" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : set wallpaper size hints (S) :- 0 : No , 1 : Yes</li>
# <li index="129" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : write Access Point Name settings (D) :- 0 : No , 1 : Yes</li>
# <li index="130" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : write subscribed feeds (D) :- 0 : No , 1 : Yes</li>
# <li index="131" class="text-base list-inside py-1 listing w-11/12 text-justify">System tools : write sync settings (D) :- 0 : No , 1 : Yes</li>
# <li index="132" class="text-base list-inside py-1 listing w-11/12 text-justify">Your accounts : Blogger (D) :- 0 : No , 1 : Yes</li>
# <li index="133" class="text-base list-inside py-1 listing w-11/12 text-justify">Your accounts : Google App Engine (D) :- 0 : No , 1 : Yes</li>
# <li index="134" class="text-base list-inside py-1 listing w-11/12 text-justify">Your accounts : Google Docs (D) :- 0 : No , 1 : Yes</li>
# <li index="135" class="text-base list-inside py-1 listing w-11/12 text-justify">Your accounts : Google Finance (D) :- 0 : No , 1 : Yes</li>
# <li index="136" class="text-base list-inside py-1 listing w-11/12 text-justify">Your accounts : Google Maps (D) :- 0 : No , 1 : Yes</li>
# <li index="137" class="text-base list-inside py-1 listing w-11/12 text-justify">Your accounts : Google Spreadsheets (D) :- 0 : No , 1 : Yes</li>
# <li index="138" class="text-base list-inside py-1 listing w-11/12 text-justify">Your accounts : Google Voice (D) :- 0 : No , 1 : Yes</li>
# <li index="139" class="text-base list-inside py-1 listing w-11/12 text-justify">Your accounts : Google mail (D) :- 0 : No , 1 : Yes</li>
# <li index="140" class="text-base list-inside py-1 listing w-11/12 text-justify">Your accounts : Picasa Web Albums (D) :- 0 : No , 1 : Yes</li>
# <li index="141" class="text-base list-inside py-1 listing w-11/12 text-justify">Your accounts : YouTube (D) :- 0 : No , 1 : Yes</li>
# <li index="142" class="text-base list-inside py-1 listing w-11/12 text-justify">Your accounts : YouTube usernames (D) :- 0 : No , 1 : Yes</li>
# <li index="143" class="text-base list-inside py-1 listing w-11/12 text-justify">Your accounts : access all Google services (S) :- 0 : No , 1 : Yes</li>
# <li index="144" class="text-base list-inside py-1 listing w-11/12 text-justify">Your accounts : access other Google services (D) :- 0 : No , 1 : Yes</li>
# <li index="145" class="text-base list-inside py-1 listing w-11/12 text-justify">Your accounts : act as an account authenticator (D) :- 0 : No , 1 : Yes</li>
# <li index="146" class="text-base list-inside py-1 listing w-11/12 text-justify">Your accounts : act as the AccountManagerService (S) :- 0 : No , 1 : Yes</li>
# <li index="147" class="text-base list-inside py-1 listing w-11/12 text-justify">Your accounts : contacts data in Google accounts (D) :- 0 : No , 1 : Yes</li>
# <li index="148" class="text-base list-inside py-1 listing w-11/12 text-justify">Your accounts : discover known accounts (S) :- 0 : No , 1 : Yes</li>
# <li index="149" class="text-base list-inside py-1 listing w-11/12 text-justify">Your accounts : manage the accounts list (D) :- 0 : No , 1 : Yes</li>
# <li index="150" class="text-base list-inside py-1 listing w-11/12 text-justify">Your accounts : read Google service configuration (S) :- 0 : No , 1 : Yes</li>
# <li index="151" class="text-base list-inside py-1 listing w-11/12 text-justify">Your accounts : use the authentication credentials of an account (D) :- 0 : No , 1 : Yes</li>
# <li index="152" class="text-base list-inside py-1 listing w-11/12 text-justify">Your accounts : view configured accounts (S) :- 0 : No , 1 : Yes</li>
# <li index="153" class="text-base list-inside py-1 listing w-11/12 text-justify">Your location : access extra location provider commands (S) :- 0 : No , 1 : Yes</li>
# <li index="154" class="text-base list-inside py-1 listing w-11/12 text-justify">Your location : coarse (network-based) location (D) :- 0 : No , 1 : Yes</li>
# <li index="155" class="text-base list-inside py-1 listing w-11/12 text-justify">Your location : fine (GPS) location (D) :- 0 : No , 1 : Yes</li>
# <li index="156" class="text-base list-inside py-1 listing w-11/12 text-justify">Your location : mock location sources for testing (D) :- 0 : No , 1 : Yes</li>
# <li index="157" class="text-base list-inside py-1 listing w-11/12 text-justify">Your messages : Read Email attachments (D) :- 0 : No , 1 : Yes</li>
# <li index="158" class="text-base list-inside py-1 listing w-11/12 text-justify">Your messages : Send Gmail (S) :- 0 : No , 1 : Yes</li>
# <li index="159" class="text-base list-inside py-1 listing w-11/12 text-justify">Your messages : edit SMS or MMS (D) :- 0 : No , 1 : Yes</li>
# <li index="160" class="text-base list-inside py-1 listing w-11/12 text-justify">Your messages : modify Gmail (D) :- 0 : No , 1 : Yes</li>
# <li index="161" class="text-base list-inside py-1 listing w-11/12 text-justify">Your messages : read Gmail (D) :- 0 : No , 1 : Yes</li>
# <li index="162" class="text-base list-inside py-1 listing w-11/12 text-justify">Your messages : read Gmail attachment previews (D) :- 0 : No , 1 : Yes</li>
# <li index="163" class="text-base list-inside py-1 listing w-11/12 text-justify">Your messages : read SMS or MMS (D) :- 0 : No , 1 : Yes</li>
# <li index="164" class="text-base list-inside py-1 listing w-11/12 text-justify">Your messages : read instant messages (D) :- 0 : No , 1 : Yes</li>
# <li index="165" class="text-base list-inside py-1 listing w-11/12 text-justify">Your messages : receive MMS (D) :- 0 : No , 1 : Yes</li>
# <li index="166" class="text-base list-inside py-1 listing w-11/12 text-justify">Your messages : receive SMS (D) :- 0 : No , 1 : Yes</li>
# <li index="167" class="text-base list-inside py-1 listing w-11/12 text-justify">Your messages : receive WAP (D) :- 0 : No , 1 : Yes</li>
# <li index="168" class="text-base list-inside py-1 listing w-11/12 text-justify">Your messages : send SMS-received broadcast (S) :- 0 : No , 1 : Yes</li>
# <li index="169" class="text-base list-inside py-1 listing w-11/12 text-justify">Your messages : send WAP-PUSH-received broadcast (S) :- 0 : No , 1 : Yes</li>
# <li index="170" class="text-base list-inside py-1 listing w-11/12 text-justify">Your messages : write instant messages (D) :- 0 : No , 1 : Yes</li>
# <li index="171" class="text-base list-inside py-1 listing w-11/12 text-justify">Your personal information : add or modify calendar events and send email to guests (D) :- 0 : No , 1 : Yes</li>
# <li index="172" class="text-base list-inside py-1 listing w-11/12 text-justify">Your personal information : choose widgets (S) :- 0 : No , 1 : Yes</li>
# <li index="173" class="text-base list-inside py-1 listing w-11/12 text-justify">Your personal information : read Browser's history and bookmarks (D) :- 0 : No , 1 : Yes</li>
# <li index="174" class="text-base list-inside py-1 listing w-11/12 text-justify">Your personal information : read calendar events (D) :- 0 : No , 1 : Yes</li>
# <li index="175" class="text-base list-inside py-1 listing w-11/12 text-justify">Your personal information : read contact data (D) :- 0 : No , 1 : Yes</li>
# <li index="176" class="text-base list-inside py-1 listing w-11/12 text-justify">Your personal information : read sensitive log data (D) :- 0 : No , 1 : Yes</li>
# <li index="177" class="text-base list-inside py-1 listing w-11/12 text-justify">Your personal information : read user defined dictionary (D) :- 0 : No , 1 : Yes</li>
# <li index="178" class="text-base list-inside py-1 listing w-11/12 text-justify">Your personal information : retrieve system internal state (S) :- 0 : No , 1 : Yes</li>
# <li index="179" class="text-base list-inside py-1 listing w-11/12 text-justify">Your personal information : set alarm in alarm clock (S) :- 0 : No , 1 : Yes</li>
# <li index="180" class="text-base list-inside py-1 listing w-11/12 text-justify">Your personal information : write Browser's history and bookmarks (D) :- 0 : No , 1 : Yes</li>
# <li index="181" class="text-base list-inside py-1 listing w-11/12 text-justify">Your personal information : write contact data (D) :- 0 : No , 1 : Yes</li>
# <li index="182" class="text-base list-inside py-1 listing w-11/12 text-justify">Your personal information : write to user defined dictionary (S) :- 0 : No , 1 : Yes</li>
# <li index="183" class="text-base list-inside py-1 listing w-11/12 text-justify">Class :- 0 : Benign , 1 : Malware</li>
# </ol>

# %% [markdown]
# # Python Code

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\ANDRIOD AUTHENTICITY PREDICTION\ANDRIOD AUTHENTICITY PREDICTION.csv")
df.sample(5)
# Out:
#                                  App                               Package  \
# 26523                Find Free Stuff                          mt.FreeStuff
# 8314                     FX anywhere                    jp.co.mobileit.mfx
# 8191      Disaster Preparedness News    com.hippyapps.disasterpreparedness
# 6074           2 Player Whack a Mole                com.wpd.game.whackmole
# 1890   Japan tsunami quake charity 2  jp.spr.adr.Prom_Live_Wallpaper_bac07
#
#                Category                                        Description  \
# 26523      Productivity  The best free stuff finder online!<p>***Please...
# 8314            Finance  ???FX anywhere??????will invite you to a new F...
# 8191   News & Magazines  This is a collection of regularly updated news...
# 6074    Arcade & Action  Play WHACK A MOLE with your friend now!<br>Get...
# 1890    Personalization  &quot;pray for japan&quot;<p>Get Well northeas...
#
#        Rating  Number of ratings  Price  \
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27310 entries, 0 to 29998
# Data columns (total 184 columns):
#  #    Column                                                                                  Dtype
# ---   ------                                                                                  -----
#  0    App                                                                                     object
#  1    Package                                                                                 object
#  2    Category                                                                                object
#  3    Description                                                                             object
#  4    Rating                                                                                  float64
#  5    Number of ratings                                                                       int64
# ...

# %%
df.shape
# Out:
# (29999, 184)

# %%
df.describe()
# Out:
#              Rating  Number of ratings         Price  \
# count  29999.000000       2.999900e+04  29999.000000
# mean       3.537215       6.852608e+03      0.625707
# std        1.424685       4.586899e+04      3.222620
# min        0.000000       0.000000e+00      0.000000
# 25%        3.300000       4.000000e+00      0.000000
# 50%        4.000000       4.600000e+01      0.000000
# 75%        4.400000       7.160000e+02      0.000000
# max        5.000000       1.908590e+06    158.070000
#
#        Dangerous permissions count  Safe permissions count  \
# count                 29795.000000            29999.000000
# mean                      3.111160                1.353978
# std                       3.052602                1.523491
# min                       0.000000                0.000000
# 25%                       1.000000                0.000000
# 50%                       2.000000                1.000000
# 75%                       4.000000                2.000000
# ...

# %%
df.isnull().sum()[df.isnull().sum()>0]
# Out:
# App                              1
# Description                      3
# Related apps                   755
# Dangerous permissions count    204
# dtype: int64

# %%
print(df.duplicated().sum())

df.drop_duplicates(inplace=True)

print(df.duplicated().sum())
# Out:
# 2689
# 0
